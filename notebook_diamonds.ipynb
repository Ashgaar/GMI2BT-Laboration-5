# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

path = "./diamonds.csv"
data = pd.read_csv(path)

# %%
data.isnull().any()
# Out:
# Unnamed: 0    False
# carat         False
# cut           False
# color         False
# clarity       False
# depth         False
# table         False
# price         False
# x             False
# y             False
# z             False
# dtype: bool

# %%
del data[data.columns[0]]
data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
data.describe().T
# Out:
#          count         mean          std    min     25%      50%      75%  \
# carat  53940.0     0.797940     0.474011    0.2    0.40     0.70     1.04
# depth  53940.0    61.749405     1.432621   43.0   61.00    61.80    62.50
# table  53940.0    57.457184     2.234491   43.0   56.00    57.00    59.00
# price  53940.0  3932.799722  3989.439738  326.0  950.00  2401.00  5324.25
# x      53940.0     5.731157     1.121761    0.0    4.71     5.70     6.54
# y      53940.0     5.734526     1.142135    0.0    4.72     5.71     6.54
# z      53940.0     3.538734     0.705699    0.0    2.91     3.53     4.04
#
#             max
# carat      5.01
# depth     79.00
# table     95.00
# price  18823.00
# x         10.74
# y         58.90
# z         31.80

# %%
data.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
data.groupby(['cut','color'])['price'].mean()
# Out:
# cut        color
# Fair       D        4291.061350
#            E        3682.312500
#            F        3827.003205
#            G        4239.254777
#            H        5135.683168
#            I        4685.445714
#            J        4975.655462
# Good       D        3405.382175
#            E        3423.644159
#            F        3495.750275
#            G        4123.482204
#            H        4276.254986
#            I        5078.532567
#            J        4574.172638
# Ideal      D        2629.094566
#            E        2597.550090
#            F        3374.939362
#            G        3720.706388
#            H        3889.334831
#            I        4451.970377
#            J        4918.186384
# Premium    D        3631.292576
#            E        3538.914420
#            F        4324.890176
#            G        4500.742134
#            H        5216.706780
#            I        5946.180672
#            J        6294.591584
# ...

# %%
plt.boxplot(data['carat'])
plt.ylabel('Carat')
plt.title('Boxplot of carat')
# Out:
# Text(0.5, 1.0, 'Boxplot of carat')

# %%
sns.violinplot(x='clarity', y='price', data=data)
plt.show()

# %%
sns.catplot(x='clarity', y='price', data=data, hue = 'cut', kind = 'bar')
plt.show()

# %%
sns.violinplot(x='clarity', y='carat', data=data)
plt.show()

# %%
sns.jointplot(x='carat', y='price', data=data)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.title('Correlation Map')
ax=sns.heatmap(data.corr(), linewidth=3.1, annot=True, center=1)

# %%
sns.lmplot(x='carat', y='price', hue = 'color', data=data)

# %%
sns.regplot(x='carat', y='price', data=data)
plt.show()

# %%
Frågor och svar:
    1. Vilket var det viktigaste när det kom till pris? De 4 c:na är carat, cut, clarity och color. Alla leder till ökat pris men det är karat(carat) som har ströst påverkan
    2. Vilka var det vanligaste i varje kategori(4 c)? Carat = Allt mellan minsta 0.2 och median 0.7. Clarity = SI1 och VS2. Color = alla diamanter är ganska dåliga på färg, G. Cut = ideal.
    Sammanfattning:
        Kollar man på "Correlation map" så ser man att Karat har stor korrelation med price, x, y och z. Där x, y, z är olika mått på diamanten.
